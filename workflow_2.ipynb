# %%
#tutorial from: https://medium.com/@randerson112358/stock-price-prediction-using-python-machine-learning-e82a039ac2bb

# %%
#Import the libraries
import math
#import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')#

DATADIR = 'stock_files'
GRAPHDIR = 'stock_graphs'
SPLITSDIR = 'split_files'

import sa_functions

# %%
online_process_stock_once('TSLA', 365)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Saved DataFrame as: [stock_files/2020-07-06/TSLA_2010-06-29_2020-07-06.csv]
# Saved Plot as: [stock_graphs/2020-07-06/TSLA_SMA_365_2019-07-07_2020-07-06.png]

# %%
# Out:
# Python version
# 3.7.3 (default, Apr 24 2020, 18:51:23)
# [Clang 11.0.3 (clang-1103.0.32.62)]
# Version info.
# sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0)
